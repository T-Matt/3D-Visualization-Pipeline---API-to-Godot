# %%
import numpy as np

path = rf"D:\GODOT_VISUAL\3d-nc\data\frames\frame_0000.bin"
arr = np.fromfile(path, dtype=np.float32)

print("count(-999):", np.sum(np.isclose(arr, -999.0, atol=1.0)))
print("count(-500):", np.sum(np.isclose(arr, -500.0, atol=1.0)))
print("min/max:", arr.min(), arr.max())
# Out:
# count(-999): 106804
# count(-500): 0
# min/max: nan nan
